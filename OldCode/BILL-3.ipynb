# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

pd.options.display.max_rows = 1000

# %%
df = pd.read_csv("mpls_crime_2017-2022.csv")
df
# Out:
#        neighborhoodCrimeStatisticsID          neighborhood  \
# 0                                  1    ** NOT ASSIGNED **
# 1                                  2    ** NOT ASSIGNED **
# 2                                  3    ** NOT ASSIGNED **
# 3                                  4    ** NOT ASSIGNED **
# 4                                  5    ** NOT ASSIGNED **
# ...                              ...                   ...
# 42235                          42236  Z_** NOT ASSIGNED **
# 42236                          42237  Z_** NOT ASSIGNED **
# 42237                          42238  Z_** NOT ASSIGNED **
# 42238                          42239  Z_** NOT ASSIGNED **
# 42239                          42240  Z_** NOT ASSIGNED **
#
#            ucrDescription  number  reportMonth  reportYear
# 0      Aggravated Assault     2.0            8        2017
# 1                   Arson     0.0            8        2017
# 2              Auto Theft     3.0            8        2017
# ...

# %%
hood_grp = df.groupby("neighborhood")

# %%
hood_grp[""].describe()
# Out:
#                                  neighborhoodCrimeStatisticsID                \
#                                                          count          mean
# neighborhood
# ** NOT ASSIGNED **                                        80.0   3172.500000
# ARMATAGE                                                  80.0   3180.500000
# AUDUBON PARK                                              80.0   3188.500000
# Armatage                                                 400.0  24292.500000
# Audubon Park                                             400.0  24300.500000
# BANCROFT                                                  80.0   3196.500000
# BELTRAMI                                                  80.0   3204.500000
# BOTTINEAU                                                 80.0   3212.500000
# BRYANT                                                    80.0   3220.500000
# BRYN - MAWR                                               80.0   3228.500000
# ...
